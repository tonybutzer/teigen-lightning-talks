# %%
import rioxarray

#See docs for rioxarray.open_rasterio

rds = rioxarray.open_rasterio(
    "./sf_all_bands.nc"
)
rds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 13, x: 605, y: 683)
# Coordinates:
#   * y            (y) float64 4.837e+06 4.837e+06 ... 4.816e+06 4.816e+06
#   * x            (x) float64 1.891e+05 1.891e+05 ... 2.072e+05 2.072e+05
#   * time         (time) object 2020-06-13 17:11:24.796711 ... 2021-08-12 17:0...
#     spatial_ref  int64 0
# Data variables:
#     coastal      (time, y, x) uint16 ...
#     qa_radsat    (time, y, x) uint16 ...
#     blue         (time, y, x) uint16 ...
#     green        (time, y, x) uint16 ...
#     red          (time, y, x) uint16 ...
#     nir08        (time, y, x) uint16 ...
#     swir16       (time, y, x) uint16 ...
#     swir22       (time, y, x) uint16 ...
#     qa_aerosol   (time, y, x) uint16 ...
#     qa_pixel     (time, y, x) uint16 ...
# Attributes:
#     crs:           EPSG:32615
#     grid_mapping:  spatial_ref

# %%
from nb_DEAPlotting import animated_timeseries

animated_timeseries(rds,output_path='./sf_animated.gif',bands = ['red', 'green', 'blue'], time_dim='time',  
      percentile_stretch=(.2,.85), interval=1200)
# Out:
# Generating 13 frame animation
#     Exporting animation to ./sf_animated.gif

# %%
! wget https://raw.githubusercontent.com/tonybutzer/data-curation/79323ea534ccce76bd8026454a013fb436395c6a/little-cloud/lib/notebookLib/notebookLib/nb_animate.py
# Out:
# --2021-11-05 19:19:54--  https://raw.githubusercontent.com/tonybutzer/data-curation/79323ea534ccce76bd8026454a013fb436395c6a/little-cloud/lib/notebookLib/notebookLib/nb_animate.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79151 (77K) [text/plain]
# Saving to: ‘nb_animate.py’
#
# nb_animate.py       100%[===================>]  77.30K  --.-KB/s    in 0.009s
#
# 2021-11-05 19:19:55 (8.32 MB/s) - ‘nb_animate.py’ saved [79151/79151]

# %%
from nb_animate import nb_animated_timeseries

# %%
nb_animated_timeseries(rds,output_path='./sf_stretch00.gif',bands = ['red', 'green', 'blue'], time_dim='time',  
      percentile_stretch=(.2,.85), interval=1200)
# Out:
# Generating 13 frame animation
#     Exporting animation to ./sf_stretch00.gif

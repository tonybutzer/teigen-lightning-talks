# %%
# !ls /usr/share/cowsay
# Out:
# beavis.zen.cow	       eyes.cow		  milk.cow	   surgery.cow
# blowfish.cow	       flaming-sheep.cow  moofasa.cow	   telebears.cow
# bong.cow	       Frogs.pm		  moose.cow	   TextBalloon.pm
# bud-frogs.cow	       ghostbusters.cow   mutilated.cow    three-eyes.cow
# bunny.cow	       head-in.cow	  ren.cow	   turkey.cow
# cheese.cow	       hellokitty.cow	  satanic.cow	   turtle.cow
# cower.cow	       kiss.cow		  sheep.cow	   tux.cow
# default.cow	       kitty.cow	  skeleton.cow	   TuxStab.pm
# dragon-and-cow.cow     koala.cow	  small.cow	   udder.cow
# DragonAndCow.pm        kosh.cow		  sodomized.cow    vader.cow
# dragon.cow	       luke-koala.cow	  stegosaurus.cow  vader-koala.cow
# elephant.cow	       mech-and-cow.cow   Stegosaurus.pm   www.cow
# elephant-in-snake.cow  MechAndCow.pm	  stimpy.cow
# Example.pm	       meow.cow		  supermilker.cow

# %%
! cowsay -e xx hello; cowsay -f bunny goodbye; cowsay -f bud-frogs "Bud Wise Er"
#! sudo yum update
#! sudo yum install -y cowsay
# Out:
#  _______
# < hello >
#  -------
#         \   ^__^
#          \  (xx)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||
#  _________
# < goodbye >
#  ---------
#   \
#    \   \
#         \ /\
#         ( )
#       .( o ).
#  _____________
# < Bud Wise Er >
#  -------------
#      \
#       \
#           oO)-.                       .-(Oo
#          /__  _\                     /_  __\
#          \  \(  |     ()~()         |  )/  /
#           \__|\ |    (-___-)        | /|__/
#           '  '--'    ==`-'==        '--'  '

# %%
! cowsay -e ^^ -f moose "This notebook brought to you by EastAfrica Veget"
# Out:
#  _________________________________
# / This notebook brought to you by \
# \ EastAfrica Veget                /
#  ---------------------------------
#   \
#    \   \_\_    _/_/
#     \      \__/
#            (^^)\_______
#            (__)\       )\/\
#                ||----w |
#                ||     ||

# %%
#! (cd ; git clone https://github.com/paulkaefer/cowsay-files.git)

# %%
! cowsay -f /home/ec2-user/cowsay-files/cows/chessmen.cow Rich Sigell does not play chess with his daughter
# Out:
#  ______________________________________
# / Rich Sigell does not play chess with \
# \ his daughter                         /
#  --------------------------------------
#     \
#      \
#       \
#        \
#                                            .::.
#                                            _::_
#                                  ()      _/____\_
#                                <~~~~>    \      /
#                        <>_      \__/      \____/      <>_
#            __/"""\   (\)  )    (____)     (____)    (\)  )   __/"""\
#   WWWWWW  ]___ 0  }   \__/      |  |       |  |      \__/   ]___ 0  }  WWWWWW
#    |  |       /   }  (____)     |  |       |__|     (____)      /   }   |  |
#    |  |     /~    }   |  |      |__|      /    \     |  |     /~    }   |  |
#    |__|     \____/    |__|     /____\    (______)    |__|     \____/    |__|
#   /____\    /____\   /____\   (______)  (________)  /____\    /____\   /____\
#  (______)  (______) (______) (________) /________\ (______)  (______) (______)
#
#     __        __       __        __         __        __        __       __
#    (  )      (  )     (  )      (  )       (  )      (  )      (  )     (  )
#     ||        ||       ||        ||         ||        ||        ||       ||
#    /__\      /__\     /__\      /__\       /__\      /__\      /__\     /__\
#   (____)    (____)   (____)    (____)     (____)    (____)    (____)   (____)

# %%
! cowsay -f /home/ec2-user/cowsay-files/cows/bobross.cow a happy little stream lives here
# Out:
#  __________________________________
# < a happy little stream lives here >
#  ----------------------------------
#       \
#         \
#           \
#             \
#               \

# %% [markdown]
# ## https://github.com/paulkaefer/cowsay-files/blob/main/examples.md

# %%
! cowsay -f /home/ec2-user/cowsay-files/cows/mule.cow you are stubborn tony!
# Out:
#  ________________________
# < you are stubborn tony! >
#  ------------------------
#      \
#       \
#   /\          /\
#  ( \\        // )
#   \ \\      // /
#    \_\\||||//_/
#      / _  _ \/
#
#      |(o)(o)|\/
#      |      | \/
#      \      /  \/_____________________
#       |____|     \\                  \\
#      /      \     ||                  \\
#      \ 0  0 /     |/                  |\\
#       \____/ \    V           (       / \\
#        / \    \     )          \     /   \\
#       / | \    \_|  |___________\   /     ""
#                   ||  |     \   /\  \
#                   ||  /      \  \ \  \
#                   || |        | |  | |
#                   || |        | |  | |
#                   ||_|        |_|  |_|
#                  //_/        /_/  /_/

# %%
! cowsay -f /home/ec2-user/cowsay-files/cows/periodic-table.cow my wife says we have no chemistry
# Out:
#  ___________________________________
# < my wife says we have no chemistry >
#  -----------------------------------
# \
#  \
#    1A   2A                                         3A  4A  5A  6A  7A  8A
#   -----                                                               -----
# 1 | H |                                                               |He |
#   |---+----                                       --------------------+---|
# 2 |Li |Be |                                       | B | C | N | O | F |Ne |
#   |---+---|                                       |---+---+---+---+---+---|
# 3 |Na |Mg |3B  4B  5B  6B  7B |    8B     |1B  2B |Al |Si | P | S |Cl |Ar |
#   |---+---+---------------------------------------+---+---+---+---+---+---|
# 4 | K |Ca |Sc |Ti | V |Cr |Mn |Fe |Co |Ni |Cu |Zn |Ga |Ge |As |Se |Br |Kr |
#   |---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---|
# 5 |Rb |Sr | Y |Zr |Nb |Mo |Tc |Ru |Rh |Pd |Ag |Cd |In |Sn |Sb |Te | I |Xe |
#   |---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---|
# 6 |Cs |Ba |LAN|Hf |Ta | W |Re |Os |Ir |Pt |Au |Hg |Tl |Pb |Bi |Po |At |Rn |
#   |---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---|
# 7 |Fr |Ra |ACT|Rf |Db |Sg |Bh |Hs |Mt |Ds |Rg |Cn |Uut|Fl |Uup|Lv |Uus|Uuo|
#   -------------------------------------------------------------------------
#               -------------------------------------------------------------
#    Lanthanide |La |Ce |Pr |Nd |Pm |Sm |Eu |Gd |Tb |Dy |Ho |Er |Tm |Yb |Lu |
#               |---+---+---+---+---+---+---+---+---+---+---+---+---+---+---|
#    Actinide   |Ac |Th |Pa | U |Np |Pu |Am |Cm |Bk |Cf |Es |Fm |Md |No |Lr |
#               -------------------------------------------------------------

# %%
import PIL.Image

def main():
    path = input("Enter the path to the image file : \n")
    try:
        image = PIL.Image.open(path)
    except:
        print(path, "Unable to find image ");

# %%
#!wget https://c.tenor.com/5GfVGVlu_YgAAAAj/qwhr.gif

# %%
# !ls
# Out:
# 0_ascii_art_python_Pil.ipynb  ascii_image.txt  qwhr.gif
# ascii_image2.txt	      h2.gif

# %%
#ASCII_CHARS = ["@", "#", "$", "%", "?", "*", "+", ";", ":", ",", "."]

# %%
#ASCII_CHARS = ["@", "#", "$", "%", "?", "*", "+", ";", ".", ",", "."]
ASCII_CHARS = ["@", "#", "$", "%", "?", "*", "+", ";", " ", ",", "."]

# %%
def resize(image, new_width = 100):
    width, height = image.size
    new_height = new_width * height / width
    return image.resize((new_width, new_height))

# %%
def to_greyscale(image):
    #return image.convert("L")
    #return image.convert("P")
    return image.convert("LA")

# %%
def pixel_to_ascii(image):
    pixels = image.getdata()
    ascii_str = "";
    for pixel in pixels:
        ascii_str += ASCII_CHARS[pixel//25];
    return ascii_str

# %%
path = 'qwhr.gif'

# %%
import PIL.Image


try:
    image = PIL.Image.open(path)
except:
    print(path, "Unable to find image ")    #resize image

# %%
width, height = image.size

# %%
width,height
# Out:
# (118, 118)

# %%
image = image.resize((45,30))

# %%
image
# Out:
# <PIL.Image.Image image mode=P size=45x30 at 0x7F49FD4B16C0>

# %%
#image = resize(image);    #convert image to greyscale image

# %%
greyscale_image = to_greyscale(image)    # convert greyscale image to ascii characters

# %%
greyscale_image
# Out:
# <PIL.Image.Image image mode=LA size=45x30 at 0x7F49FD4B1FF0>

# %%
 greyscale_image.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=45x30 at 0x7F49FD4B2530>

# %%
 gs2 = greyscale_image.convert("L")

# %%
ascii_str = pixel_to_ascii(gs2)

# %%
ascii_str
# Out:
# '@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@%             *@@@@@@@@@@@@@@@@@@@@@@@@@@@+                   ?@@@@@@@@@@@@@@@@@@@@@@%                       ;@@@@@@@@@@@@@@@@@@@                           %@@@@@@@@@@@@@@@#                             +@@@@@@@@@@@@@+                               ?@@@@@@@@@@@#         *             @         +@@@@@@@@@@        ;@@@           @@@+        @@@@@@@@@         @@@@          ?@@@@        ;@@@@@@@@         @@@@          *@@@@         @@@@@@@@         ?@@@           @@@+         @@@@@@@$          @@*            @?          @@@@@@@%                                     #@@@@@@#                                     @@@@@@@@                                     @@@@@@@@                                *    @@@@@@@@?    @%                        @@   $@@@@@@@@@;   *@;                      @#    @@@@@@@@@@@     @;                    @@    @@@@@@@@@@@@@     @@                 *@;    @@@@@@@@@@@@@@@     *@@;            $@@     @@@@@@@@@@@@@@@@@*      #@@@@@##@@@@@*     %@@@@@@@@@@@@@@@@@@@@+                     ?@@@@@@@@@@@@@@@@@@@@@@@@@                 %@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@%;       ;$@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@'

# %%
img_width = gs2.width
ascii_str_len = len(ascii_str)
ascii_img=""    #Split the string based on width  of the image
for i in range(0, ascii_str_len, img_width):
    ascii_img += ascii_str[i:i+img_width] + "\n"    #save the string to a file
with open("ascii_image.txt", "w") as f:
    f.write(ascii_img);

# %%
! ls
# Out:
# 0_ascii_art_python_Pil.ipynb  ascii_image.txt  qwhr.gif
# ascii_image2.txt	      h2.gif

# %%
cat ascii_image.txt
# Out:
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@#@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@%             *@@@@@@@@@@@@@
# @@@@@@@@@@@@@@+                   ?@@@@@@@@@@
# @@@@@@@@@@@@%                       ;@@@@@@@@
# @@@@@@@@@@@                           %@@@@@@
# @@@@@@@@@#                             +@@@@@
# @@@@@@@@+                               ?@@@@
# @@@@@@@#         *             @         +@@@
# @@@@@@@        ;@@@           @@@+        @@@
# @@@@@@         @@@@          ?@@@@        ;@@
# @@@@@@         @@@@          *@@@@         @@
# @@@@@@         ?@@@           @@@+         @@
# @@@@@$          @@*            @?          @@
# @@@@@%                                     #@
# @@@@@#                                     @@
# @@@@@@                                     @@
# @@@@@@                                *    @@
# @@@@@@?    @%                        @@   $@@
# @@@@@@@;   *@;                      @#    @@@
# @@@@@@@@     @;                    @@    @@@@
# @@@@@@@@@     @@                 *@;    @@@@@
# @@@@@@@@@@     *@@;            $@@     @@@@@@
# @@@@@@@@@@@*      #@@@@@##@@@@@*     %@@@@@@@
# @@@@@@@@@@@@@+                     ?@@@@@@@@@
# @@@@@@@@@@@@@@@@                 %@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@%;       ;$@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
# !ls /home/ec2-user/cowsay-files/cows
# Out:
# 47.cow		       greedo.cow		 raphael3.cow
# abu-apple.cow	       grinch.cow		 raphael4.cow
# abu.cow		       grunty.cow		 raphael5.cow
# ackbar.cow	       guy-fawkes.cow		 raphael.cow
# admiral-ackbar.cow     hammerhead.cow		 raphael-error2.cow
# agent-smith.cow        hanuman.cow		 raphael-error.cow
# aladdin2.cow	       happy-whale.cow		 raptor.cow
# aladdin.cow	       harley-quinn.cow		 raptor-jesus.cow
# alf.cow		       hawking.cow		 rash.cow
# alfred.cow	       head.cow			 rayman2.cow
# amy.cow		       hitman.cow		 rayman.cow
# aperture-blank.cow     hitman-face.cow		 rick-and-morty2.cow
# aperture.cow	       hl2-dog.cow		 rick-and-morty.cow
# archer.cow	       hodor.cow		 rick-and-morty-running.cow
# armadillo.cow	       homer.cow		 riddler.cow
# arya.cow	       homer-simpson.cow	 ripster.cow
# assassin2.cow	       homestar.cow		 roadrunner2.cow
# assassin.cow	       hulk.cow			 roadrunner.cow
# atat.cow	       humba-wumba.cow		 ROB.cow
# atom.cow	       hypnotoad.cow		 roberto.cow
# atst-atat.cow	       ignignokt.cow		 roberto-face.cow
# awesome-face.cow       ike.cow			 robin.cow
# baby_yoda.cow	       indiana-jones.cow	 robocop2.cow
# banana.cow	       ironman2.cow		 robocop.cow
# banjo.cow	       ironman.cow		 robot.cow
# banjo-kazooie.cow      isaac.cow		 robot-devil.cow
# barney2.cow	       it.cow			 robotfindskitten.cow
# barney.cow	       it-crowd.cow		 rocko.cow
# bart.cow	       jab.cow			 roflcopter.cow
# bart-zombie.cow        jafar.cow		 ron-swanson.cow
# batman2.cow	       jamjars.cow		 rook.cow
# batman.cow	       jaws2.cow		 roy.cow
# batman-genesis.cow     jaws.cow			 roz.cow
# batman-toon2.cow       jellyfish.cow		 ryu.cow
# batman-toon.cow        jesus-ripped.cow		 samus2.cow
# bees.cow	       jigsaw.cow		 samus3.cow
# bender.cow	       joffrey.cow		 samus-cannon.cow
# bender-md.cow	       john-snow.cow		 samus.cow
# biggs.cow	       joker.cow		 scar.cow
# big-slammu.cow	       joker-toon.cow		 scarecrow.cow
# bill-the-cat.cow       kazooie.cow		 scary-terry-face.cow
# biohazard.cow	       ken.cow			 scooby-doo.cow
# bioshock.cow	       kenny.cow		 scorpion.cow
# bishop.cow	       khal-drogo.cow		 scrooge-mcduck.cow
# black-mesa.cow	       kilroy.cow		 scruffy.cow
# bob2.cow	       king.cow			 seahorse-big.cow
# boba-fett.cow	       kirby.cow		 seahorse.cow
# bob.cow		       kitten.cow		 shadow.cow
# bobross2.cow	       knight.cow		 shaggy.cow
# bobross.cow	       knuckles2.cow		 shark-dude.cow
# bomberman2.cow	       knuckles.cow		 shark-smiling.cow
# bomberman.cow	       krishna.cow		 sheik.cow
# borat_2.cow	       kyle.cow			 sherlock.cow
# borat.cow	       lahey.cow		 shiva.cow
# bottles.cow	       lara-croft2.cow		 shredder2.cow
# bowser.cow	       lara-croft.cow		 shredder.cow
# bowser-jr.cow	       larry2.cow		 shredder-snes.cow
# box.cow		       larry.cow		 shrek.cow
# broken-heart.cow       lebowski-walter.cow	 simba.cow
# bruce.cow	       leela.cow		 skull-kid.cow
# bsod.cow	       leia2.cow		 sleepycat.cow
# bugs-bunny.cow	       leia.cow			 smiling-octopus.cow
# bugs-bunny-error.cow   leonardo2.cow		 smith.cow
# bulbasaur.cow	       leonardo3.cow		 snoopy.cow
# buzz-lightyear.cow     leonardo4.cow		 snowball.cow
# c3po-color.cow	       leonardo.cow		 solid-snake2.cow
# C3PO.cow	       leonardo-error2.cow	 solid-snake.cow
# cake.cow	       leonardo-error.cow	 solo.cow
# cake-with-candles.cow  leon.cow			 sonic2.cow
# calculon.cow	       leprechaun.cow		 sonic3.cow
# captain-america.cow    liberty.cow		 sonic.cow
# captain-falcon2.cow    lightbulb.cow		 sonic-error.cow
# captain-falcon.cow     linda.cow		 space-ghost.cow
# carl.cow	       link2.cow		 speedy-gonzales.cow
# cartman.cow	       link3.cow		 spiderman.cow
# catbert.cow	       link.cow			 splinter2.cow
# cat.cow		       link-toon.cow		 splinter.cow
# catdog.cow	       link-windwaker.cow	 spongebob.cow
# catwoman.cow	       llama.cow		 squanchy.cow
# charlie-brown.cow      lobster.cow		 squirtle.cow
# charmander.cow	       lollerskates.cow		 stan.cow
# cheat.cow	       louise.cow		 starfox2.cow
# chef.cow	       luigi.cow		 starfox3.cow
# chessmen.cow	       lumbergh.cow		 starfox.cow
# chewbacca.cow	       magneto2.cow		 stewie.cow
# claw-arm.cow	       magneto.cow		 stick-figure.cow
# clippy.cow	       mailchimp.cow		 stormtrooper.cow
# col-sanders.cow        mario.cow		 streex.cow
# companion-cube.cow     marth.cow		 strongbad.cow
# cthulhu.cow	       marth-toon.cow		 stu.cow
# cthulhu-mini.cow       martian.cow		 subzero.cow
# cube.cow	       master-chief.cow		 sudowoodo.cow
# cyclops2.cow	       master-shake.cow		 superman-batman.cow
# cyclops.cow	       max-payne.cow		 superman.cow
# daenerys.cow	       maze-runner.cow		 superman-cyborg.cow
# daffy-duck.cow	       meatwad.cow		 superman-flying.cow
# dalek.cow	       meeseeks.cow		 super-mario-world.cow
# dalek-shooting.cow     megaman.cow		 sylvester.cow
# darth-vader.cow        megazord.cow		 tails2.cow
# darwin.cow	       melisandre.cow		 tails.cow
# deadpool-bob-ross.cow  metaknight.cow		 tails-error.cow
# deadpool.cow	       metal-gear.cow		 taxi.cow
# deadpool-face.cow      mew.cow			 taz.cow
# deadspace.cow	       mewtwo2.cow		 terminator.cow
# death.cow	       mewtwo.cow		 tesla.cow
# deus-ex.cow	       michaelangelo2.cow	 tf2-demo.cow
# dilbert-boss.cow       michaelangelo3.cow	 tf2-engineer.cow
# dilbert.cow	       michaelangelo.cow	 tf2-heavy.cow
# dishonored.cow	       michaelangelo-error2.cow  tf2-medic.cow
# doc-and-marty.cow      michaelangelo-error.cow	 tf2-pyro.cow
# dogbert.cow	       michael-jackson.cow	 tf2-scout.cow
# dog.cow		       mike-tyson.cow		 tf2-sniper.cow
# dolphin.cow	       milton.cow		 tf2-soldier.cow
# donald.cow	       minion2.cow		 tf2-spy2.cow
# donald-duck-angry.cow  minion.cow		 tf2-spy.cow
# donald-duck.cow        minion-laugh.cow		 tf2-spy-knife.cow
# donald-hat.cow	       moltar.cow		 the-boss.cow
# donatello2.cow	       mona-lisa.cow		 the-dude.cow
# donatello3.cow	       mooninites.cow		 the-hound.cow
# donatello.cow	       morpheus.cow		 the-jesus.cow
# donatello-error2.cow   moss.cow			 this-is-fine.cow
# donatello-error.cow    mr-freeze.cow		 thor.cow
# donkey.cow	       mr-pb.cow		 threecubes.cow
# donkeykong.cow	       mr-robot-hal.cow		 tim.cow
# doomguy.cow	       mr-x.cow			 tina.cow
# doomkart2.cow	       mule.cow			 toast.cow
# doomkart.cow	       mumbo-jumbo.cow		 toaster.cow
# dr-mario.cow	       ned-stark.cow		 tombraider.cow
# dr-robotnik.cow        nemo.cow			 tortoise.cow
# earthworm-jim.cow      neo.cow			 true-color
# einstein.cow	       ness.cow			 tux-big.cow
# einstein-face.cow      nyan.cow			 tweety-bird.cow
# elephant2.cow	       obi-wan.cow		 twoface.cow
# elmer-fudd.cow	       octopus.cow		 tyrion.cow
# err.cow		       one-punch-man.cow	 tywin.cow
# eve.cow		       owl.cow			 USA.cow
# ewok.cow	       palpatine.cow		 vader.cow
# explosion.cow	       pawn.cow			 varys.cow
# falco.cow	       peach.cow		 vault-boy.cow
# farnsworth.cow	       peep-show.cow		 venom.cow
# fat-banana.cow	       penguin.cow		 ventriloquist.cow
# fat-cow.cow	       pepe.cow			 vishnu.cow
# fire.cow	       periodic-table.cow	 vortigaunt.cow
# flintstone2.cow        personality-sphere.cow	 wall-e2.cow
# flintstone.cow	       peter-pan.cow		 wall-e.cow
# fox.cow		       phasma.cow		 wall-e-plant.cow
# fox-winking.cow        pickle-rick2.cow		 wally.cow
# freeman2.cow	       pickle-rick.cow		 walter.cow
# freeman.cow	       pickle-rick-face.cow	 walter-white.cow
# freeman-face.cow       pikachu2.cow		 wario.cow
# frylock.cow	       pikachu3.cow		 weeping-angel.cow
# fry-money.cow	       pikachu.cow		 whale.cow
# fsm2.cow	       pikachu-jason.cow	 wheatley.cow
# fsm.cow		       pimple.cow		 white-walker.cow
# fsm-creation.cow       pinball-machine.cow	 wile-e-coyote2.cow
# gandalf.cow	       pit.cow			 wizard.cow
# ganesha.cow	       pizza-phone.cow		 wolverine.cow
# ganondorf.cow	       plankton.cow		 wolverine-error.cow
# garfield.cow	       plutonian.cow		 wolverine-genesis.cow
# gene.cow	       pod.cow			 wolverine-snes.cow
# genie.cow	       poison-ivy.cow		 world.cow
# ghostbusters.cow       popeye.cow		 yoda.cow
# ghost.cow	       portal-chell.cow		 yosemite-sam.cow
# ghostface.cow	       portal-turrets.cow	 yoshi.cow
# giving-bunny.cow       prof.cow			 zapp-kif.cow
# glados2.cow	       professor.cow		 zelda.cow
# glados-color.cow       pterodactyl.cow		 zitz.cow
# glados.cow	       queen.cow		 zoidberg2.cow
# glados-potato.cow      r2d2-c3po.cow		 zoidberg.cow
# glados-wrecked.cow     r2d2.cow			 zombie.cow
# golden-eagle.cow       R2-D2.cow		 zombie-police.cow
# good-vs-evil.cow       radio.cow		 zorak.cow
# gray-fox2.cow	       rama.cow
# gray-fox.cow	       raphael2.cow

# %%
! for ff in $(ls /home/ec2-user/cowsay-files/cows/tax*) ; do cowsay -f $ff $ff ; done
# Out:
#  _________________________________________
# / /home/ec2-user/cowsay-files/cows/taxi.c \
# \ ow                                      /
#  -----------------------------------------
#      \
#       \
#                    [\
#               .----' `-----.
#              //^^^^;;^^^^^^`\
#      _______//_____||_____()_\________
#     /826    :      : ___              `\
#    |>   ____;      ;  |/\><|   ____   _<)
#   {____/    \_________________/    \____}
#        \ '' /                 \ '' /
#  jgs    '--'                   '--'

# %%
! for ff in $(ls /home/ec2-user/cowsay-files/cows/dil*) ; do cowsay -f $ff $ff ; done
# Out:
#  _________________________________________
# / /home/ec2-user/cowsay-files/cows/dilber \
# \ t-boss.cow                              /
#  -----------------------------------------
#           \
#            \
#             \
#              \
#               \
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  _________________________________________
# / /home/ec2-user/cowsay-files/cows/dilber \
# \ t.cow                                   /
#  -----------------------------------------
#           \
#            \
#             \
#              \
#               \

# %%
! for ff in $(ls /home/ec2-user/cowsay-files/cows/arm*) ; do cowsay -f $ff $ff ; done
# Out:
#  _________________________________________
# / /home/ec2-user/cowsay-files/cows/armadi \
# \ llo.cow                                 /
#  -----------------------------------------
#          \
#           \
#                ,.-----__
#             ,:::://///,:::-.
#            /:''/////// ``:::`;/|/
#           /'   ||||||     :://'`\
#         .' ,   ||||||     `/(  e \
#   -===~__-'\__X_`````\_____/~`-._ `.
#               ~~        ~~       `~-'

# %%
! for ff in $(ls /home/ec2-user/cowsay-files/cows/wor*) ; do cowsay -f $ff $ff ; done
# Out:
#  _________________________________________
# / /home/ec2-user/cowsay-files/cows/world. \
# \ cow                                     /
#  -----------------------------------------
#    \
#     \
#           _,--',   _._.--._____
#    .--.--';_'-.', ";_      _.,-'
#   .'--'.  _.'    {`'-;_ .-.>.'
#         '-:_      )  / `' '=.
#           ) >     {_/,     /~)
#   snd     |/               `^ .'

# %%
! for ff in $(ls /home/ec2-user/cowsay-files/cows/toaste*) ; do cowsay -f $ff $ff ; done
# Out:
#  _________________________________________
# / /home/ec2-user/cowsay-files/cows/toaste \
# \ r.cow                                   /
#  -----------------------------------------
#    \                     .___________.
#     \                    |           |
#      \    ___________.   |  |    /~\ |
#          / __   __  /|   | _ _   |_| |
#         / /:/  /:/ / |   !________|__!
#        / /:/  /:/ /  |            |
#       / /:/  /:/ /   |____________!
#      / /:/  /:/ /    |
#     / /:/  /:/ /     |
#    /  ~~   ~~ /      |
#    |~~~~~~~~~~|      |
#    |    ::    |     /
#    |    ==    |    /
#    |    ::    |   /
#    |    ::    |  /
#    |    ::  @ | /
#    !__________!/

# %%
! for ff in $(ls /home/ec2-user/cowsay-files/cows/boba*) ; do cowsay -f $ff This is the Way! ; done
# Out:
#  __________________
# < This is the Way! >
#  ------------------
#               \
#                 \
#                   \
#                     \
#                       \
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     \
#
#
#                                                       \
#
#
#
#
#
#
#
#
#                                                                       \
#                                 \
#                                   \

# %%
#! wget http://www.clipartbest.com/cliparts/4T9/o5b/4T9o5bEbc. hap2.gif

# %%
#! mv 4T9o5bEbc. h2.gif
#! rm 4T*

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("h2.gif")
plt.imshow(img)

# %%
path='h2.gif'
image = PIL.Image.open(path)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=601x601 at 0x7F4A18D13C70>

# %%
ASCII_CHARS = ["@", "#", "$", "%", "?", "*", "-", ";", " ", ".", " "]

# %%
image = image.resize((60,25))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=60x25 at 0x7F4A190309D0>

# %%
greyscale_image = to_greyscale(image)    # convert greyscale image to ascii characters

# %%
gs2 = greyscale_image.convert("L")

# %%
ascii_str = pixel_to_ascii(gs2)
img_width = gs2.width
ascii_str_len = len(ascii_str)
ascii_img=""    #Split the string based on width  of the image
for i in range(0, ascii_str_len, img_width):
    ascii_img += ascii_str[i:i+img_width] + "\n"    #save the string to a file
with open("ascii_image2.txt", "w") as f:
    f.write(ascii_img);

# %%
cat ascii_image2.txt
# Out:
#                    .. ;;---******---;; ..
#               . ;-**---;;;       ;;;;---**-; .
#            .;-**-;                        ;-**-;.
#           **-;                                ;-**
#        ;?*;                                      ;*?;
#       ?*;                           ;*%%*;         ;*?
#     -%;                            ;#@@@@#;          ;%-
#    ??           ;-?%%%%?-;         $@@@@@@$            ??
#   *?           ;#@@####@@$         $@@@@@@$             ?*
#  ;$             -*-    -*;         -@@@@@@-              $;
#  %-                                 -%##%-               -%
#  $                                                        $.
#  $                                                        $
#  $                                                        $.
#  %-        -%###-                          ?##$?;        -%
#  ;$       %@@@@%;                          -$@@@@-       $;
#   *?     ;@@@$@@@$*-;                  ;-?#@@#$@@%      ?*
#    ??     ;*- ;*%#@@@#%?*--;;;;;;-**?$#@@@$?-  **;     ?*
#     -%;           ;*?$#@@@@@@@@@@@@@#$%?-;           ;%-
#       ?*;               ;;---*----;;               ;*?
#        ;?*;                                      ;*?;
#           **-;                                ;-**
#            .;-**-;                        ;-**-;.
#               . ;--*---;;;;      ;;;;---*--;.
#                    .. ;;----****----;; ..

# %%
! ls *.png
# Out:
# github-circle_1.png

# %%
ASCII_CHARS = ["@", "#", "$", "%", "?", "*", "-", ";", " ", ".", " "]

# %%
path='github-circle_1.png'
image = PIL.Image.open(path)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512 at 0x7F49FC89C880>

# %%
image = image.resize((50,34))
#image = image.resize((50,28))



image
# Out:
# <PIL.Image.Image image mode=RGBA size=50x34 at 0x7F49FC5FA320>

# %%
gs = image.convert("P")

# %%
gs
# Out:
# <PIL.Image.Image image mode=P size=50x34 at 0x7F49FC813790>

# %%
#greyscale_image = to_greyscale(image)    # convert greyscale image to ascii characters

# %%
#greyscale_image

# %%
ascii_str = pixel_to_ascii(gs)
img_width = gs2.width
ascii_str_len = len(ascii_str)
ascii_img=""    #Split the string based on width  of the image
for i in range(0, ascii_str_len, img_width):
    ascii_img += ascii_str[i:i+img_width] + "\n"    #save the string to a file
with open("github.txt", "w") as f:
    f.write(ascii_img);

# %%
cat github.txt
# Out:
#                 @@@@@@@@@@@@@@@@@@
#              @@@@@@@@@@@@@@@@@@@@@@@@
#           @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#         @@@@@@@@@@@@          @@@@@@@@@@@@
#        @@@@@@@@                    @@@@@@@@
#       @@@@@@@                        @@@@@@@
#      @@@@@@  @@@@                  @@  @@@@@@
#     @@@@@@  @@@@@@@  @@@@@@@@  @@@@@@@  @@@@@@
#    @@@@@    @@@@@@@@@@@@@@@@@@@@@@@@@@    @@@@@
#   @@@@@     @@@@@@@@@@@@@@@@@@@@@@@@@@     @@@@@
#  @@@@@      @@@@@@@@@@@@@@@@@@@@@@@@@@      @@@@@
#  @@@@       @@@@@@@@@@@@@@@@@@@@@@@@@@@      @@@@
# @@@@@      @@@@@@@@@@@@@@@@@@@@@@@@@@@@      @@@@@
# @@@@      @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@      @@@@
# @@@@      @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@      @@@@
# @@@@      @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@      @@@@
# @@@@      @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@      @@@@
# @@@@      @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@      @@@@
# @@@@       @@@@@@@@@@@@@@@@@@@@@@@@@@@@       @@@@
# @@@@       @@@@@@@@@@@@@@@@@@@@@@@@@@@@       @@@@
# @@@@        @@@@@@@@@@@@@@@@@@@@@@@@@@        @@@@
# @@@@@    @   @@@@@@@@@@@@@@@@@@@@@@@@        @@@@@
#  @@@@    @@@    @@@@@@@@@@@@@@@@@@           @@@@
#  @@@@@   @@@@       @@@@@@@@@@@             @@@@@
#   @@@@@   @@@@@@  @@@@@@@@@@@@@            @@@@@
#    @@@@@   @@@@@@@@@@@@@@@@@@@@           @@@@@
#     @@@@@@  @@@@@@@@@@@@@@@@@@@         @@@@@@
#      @@@@@@   @@@@@@@@@@@@@@@@@        @@@@@@
#       @@@@@@@      @@@@@@@@@@@@      @@@@@@@
#        @@@@@@@@    @@@@@@@@@@@@    @@@@@@@@
#         @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#           @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#              @@@@@@@@@@@@@@@@@@@@@@@@
#                 @@@@@@@@@@@@@@@@@@

# %% [markdown]
# # https://www.asciiart.eu/buildings-and-places/castles

# %% [markdown]
# ```
# /\__  _\                            /\  _`\           /\ \__
# \/_/\ \/    ___     ___    __  __   \ \ \L\ \   __  __\ \ ,_\  ____       __   _ __
#    \ \ \   / __`\ /' _ `\ /\ \/\ \   \ \  _ <' /\ \/\ \\ \ \/ /\_ ,`\   /'__`\/\`'__\
#     \ \ \ /\ \L\ \/\ \/\ \\ \ \_\ \   \ \ \L\ \\ \ \_\ \\ \ \_\/_/  /_ /\  __/\ \ \/
#      \ \_\\ \____/\ \_\ \_\\/`____ \   \ \____/ \ \____/ \ \__\ /\____\\ \____\\ \_\
#       \/_/ \/___/  \/_/\/_/ `/___/> \   \/___/   \/___/   \/__/ \/____/ \/____/ \/_/
#                                /\___/
#                                \/__/
#
# ```

# %% [markdown]
# http://www.network-science.de/ascii/

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from IPython import display
gifPath ='./github-circle_1.png'
# Display GIF in Jupyter, CoLab, IPython
with open(gifPath,'rb') as f:
    display.Image(data=f.read(), format='png')

# %%
gifPath ='./h2.gif'
# Display GIF in Jupyter, CoLab, IPython
with open(gifPath,'rb') as f:
    display.Image(data=f.read(), format='gif')
